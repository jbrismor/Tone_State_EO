# %% [markdown]
# # Data Cleaning
#
# This notebook is used to clean the data for the State Election Officials social media posts.

# %%
# read csv
import pandas as pd

df1 = pd.read_csv('CEO Nov 2022 posts_1743554102.csv')
df2 = pd.read_csv('CEO Oct 2022 posts_1743554102.csv')
df3 = pd.read_csv('CEO Sept 2022 posts_1743554102.csv')

# %%
df1.head()
# Out:
#      PostId                                            PostUrl  \
# 0  80074859           https://www.instagram.com/p/ClmjqIFveun/
# 1  80069324           https://www.instagram.com/p/ClmdWDUPnPO/
# 2  80072838  https://www.facebook.com/100057729714234/posts...
# 3  80076411  https://twitter.com/MNSecofState/status/159807...
# 4  80107630  https://twitter.com/md_sbe/status/159807020264...
#
#    PostEngagement   Platform  ChannelID                     ChannelName  \
# 0             NaN  Instagram    9955344                    John Merrill
# 1             NaN  Instagram    9955344                    John Merrill
# 2             NaN   Facebook    8894188  Secretary of State Steve Simon
# 3             NaN    Twitter    8891709    Minnesota Secretary of State
# 4             NaN    Twitter    8891704              Maryland Elections
#
#       ChannelUid     ChannelUrl  \
# 0  blank_for_now  blank_for_now
# 1  blank_for_now  blank_for_now
# 2  blank_for_now  blank_for_now
# 3  blank_for_now  blank_for_now
# 4  blank_for_now  blank_for_now
#
#                                    ChannelEngagement  \
# 0  {"follower_count":3406,"following_count":0,"li...
# 1  {"follower_count":3406,"following_count":0,"li...
# 2  {"follower_count":3963,"following_count":0,"li...
# 3  {"follower_count":4380,"following_count":330,"...
# 4  {"follower_count":4867,"following_count":231,"...
#
#                                       post_body_text  ...  \
# 0  While in Camden today I had the privilege to v...  ...
# 1  I had a great visit this afternoon with the Wi...  ...
# 2  On November 29, the State Canvassing Board cer...  ...
# 3  The State Canvassing Board certified the 2022 ...  ...
# 4  RT @BaltCoElections: To all Baltimore County E...  ...
#
#                published_at          post_data  \
# 0  2022-11-30T22:49:47.000Z  post data removed
# 1  2022-11-30T21:54:37.000Z  post data removed
# 2  2022-11-30T21:45:30.000Z  post data removed
# 3  2022-11-30T21:44:00.000Z  post data removed
# 4  2022-11-30T21:43:21.000Z  post data removed
#
#                                      post_media_urls LikesCount SharesCount  \
# 0  https://www.junkipedia.org/rails/active_storag...         13           0
# 1  https://www.junkipedia.org/rails/active_storag...          7           0
# 2                                                NaN          4           2
# 3                                                NaN          1           1
# 4                                                NaN          0           3
#
#   CommentsCount  ViewsCount  post_media_file  embedded_post_text  search_data
# 0             0         0.0              NaN                 NaN          NaN
# 1             0         0.0              NaN                 NaN          NaN
# 2             0         0.0              NaN                 NaN          NaN
# 3             0         0.0              NaN                 NaN          NaN
# 4             0         0.0              NaN                 NaN          NaN
#
# [5 rows x 23 columns]

# %%
# number of rows in each dataframe
print(len(df1))
print(len(df2))
print(len(df3))
# Out:
# 3983
# 3864
# 2027

# %%
# Keep only the columns we need: PostId, post_body_text, GoogleAudioText, VoskAudioText, EmbeddedContentText
df1 = df1[['PostId', 'post_body_text', 'GoogleAudioText', 'EmbeddedContentText', 'Platform', 'ChannelID']]
df2 = df2[['PostId', 'post_body_text', 'GoogleAudioText', 'EmbeddedContentText', 'Platform', 'ChannelID']]
df3 = df3[['PostId', 'post_body_text', 'GoogleAudioText', 'EmbeddedContentText', 'Platform', 'ChannelID']]
# Concatenate the dataframes
df = pd.concat([df1, df2, df3], ignore_index=True)
df.head()
# Out:
#      PostId                                     post_body_text  \
# 0  80074859  While in Camden today I had the privilege to v...
# 1  80069324  I had a great visit this afternoon with the Wi...
# 2  80072838  On November 29, the State Canvassing Board cer...
# 3  80076411  The State Canvassing Board certified the 2022 ...
# 4  80107630  RT @BaltCoElections: To all Baltimore County E...
#
#   GoogleAudioText EmbeddedContentText   Platform  ChannelID
# 0                                 NaN  Instagram    9955344
# 1                                 NaN  Instagram    9955344
# 2                                 NaN   Facebook    8894188
# 3                                 NaN    Twitter    8891709
# 4                                 NaN    Twitter    8891704

# %%
# unique GoogleAudioText
df['GoogleAudioText'].unique()
# Out:
# array([' ',
#        " every single republican in congress voted against this bill but against lower prescription drug prices against lowering healthcare costs against the fair taxes every single republican every single one voted against tackling the climate crisis against lowering our energy costs against creating good paying jobs my fellow americans that's the choice we face face democrats sided with the american people and every single republican in congress sided with the special interests in this boat"],
#       dtype=object)

# %%
# make ' ' to NaN in GoogleAudioText
df['GoogleAudioText'] = df['GoogleAudioText'].replace(' ', pd.NA)
# make ' ' to NaN in EmbeddedContentText
df['EmbeddedContentText'] = df['EmbeddedContentText'].replace(' ', pd.NA)

# replace NaN with empty string
df['GoogleAudioText'] = df['GoogleAudioText'].fillna('')
df['EmbeddedContentText'] = df['EmbeddedContentText'].fillna('')

# %%
# make extra column CombinedText with post_body_text and GoogleAudioText and EmbeddedContentText
df['CombinedText'] = df['post_body_text'] + ' ' + df['GoogleAudioText'] + ' ' + df['EmbeddedContentText']
# # make ' ' to NaN in CombinedText
# df['CombinedText'] = df['CombinedText'].replace(' ', pd.NA)

# # make '  ' to ' ', remove extra spaces
# df['CombinedText'] = df['CombinedText'].replace('  ', ' ')

# %%
df.head()
# Out:
#      PostId                                     post_body_text  \
# 0  80074859  While in Camden today I had the privilege to v...
# 1  80069324  I had a great visit this afternoon with the Wi...
# 2  80072838  On November 29, the State Canvassing Board cer...
# 3  80076411  The State Canvassing Board certified the 2022 ...
# 4  80107630  RT @BaltCoElections: To all Baltimore County E...
#
#   GoogleAudioText EmbeddedContentText   Platform  ChannelID  \
# 0                                      Instagram    9955344
# 1                                      Instagram    9955344
# 2                                       Facebook    8894188
# 3                                        Twitter    8891709
# 4                                        Twitter    8891704
#
#                                         CombinedText
# 0  While in Camden today I had the privilege to v...
# 1  I had a great visit this afternoon with the Wi...
# 2  On November 29, the State Canvassing Board cer...
# 3  The State Canvassing Board certified the 2022 ...
# 4  RT @BaltCoElections: To all Baltimore County E...

# %%
# write to csv
df.to_csv('text_2022.csv', index=False)

# %%
# read csv

df_24 = pd.read_csv('2024_No_Lables.csv')

# %%
df_24.head()
# Out:
#       PostId                                            PostUrl  \
# 0  392353290  https://twitter.com/IowaSOS/status/18677126733...
# 1  392438642  https://www.facebook.com/IASecretaryofState/po...
# 2  392438644     https://www.facebook.com/reel/601785225881752/
# 3  392552204           https://www.instagram.com/p/DDiL9SSOtDX/
# 4  392445383  https://www.facebook.com/ARSecofState/posts/pf...
#
#    PostEngagement         Platform  ChannelID  \
# 0             NaN          Twitter    8403193
# 1             NaN         Facebook    8402424
# 2             NaN         Facebook    8402424
# 3             NaN  InstagramDirect   26302501
# 4             NaN         Facebook    8894196
#
#                                  ChannelName     ChannelUid     ChannelUrl  \
# 0          Iowa Secretary of State Paul Pate  blank_for_now  blank_for_now
# 1          Iowa Secretary of State Paul Pate  blank_for_now  blank_for_now
# 2          Iowa Secretary of State Paul Pate  blank_for_now  blank_for_now
# 3                                  Paul Pate  blank_for_now  blank_for_now
# 4  Arkansas Secretary of State John Thurston  blank_for_now  blank_for_now
#
#                                    ChannelEngagement  \
# 0  {"follower_count":10134,"following_count":2397...
# 1  {"follower_count":12966,"following_count":0,"l...
# 2  {"follower_count":12966,"following_count":0,"l...
# 3  {"follower_count":1517,"following_count":697,"...
# 4  {"follower_count":5970,"following_count":0,"li...
#
#                                       post_body_text  ...  \
# 0  Happy Birthday to the @USNationalGuard @Nation...  ...
# 1  Happy Birthday to the National Guard! Today, w...  ...
# 2  Moments of harmony in the Iowa State Capitol. ...  ...
# 3  Moments of harmony in the Iowa State Capitol. ...  ...
# 4                                                NaN  ...
#
#                published_at          post_data post_media_urls LikesCount  \
# 0  2024-12-13T23:26:16.000Z  post data removed             NaN        0.0
# 1  2024-12-13T23:26:15.000Z  post data removed             NaN        7.0
# 2  2024-12-13T21:48:01.000Z  post data removed             NaN       27.0
# 3  2024-12-13T21:47:53.000Z  post data removed             NaN       13.0
# 4  2024-12-13T21:06:10.000Z  post data removed             NaN        0.0
#
#   SharesCount CommentsCount  ViewsCount  \
# 0         0.0             2         193
# 1         0.0             0           0
# 2         9.0             0         205
# 3         0.0             0          58
# 4         0.0             0           0
#
#                                      post_media_file  \
# 0                                                NaN
# 1                                                NaN
# 2  https://www.junkipedia.org/rails/active_storag...
# 3                                                NaN
# 4                                                NaN
#
#                                   embedded_post_text  search_data
# 0                                                NaN          NaN
# 1                                                NaN          NaN
# 2                                                NaN          NaN
# 3                                                NaN          NaN
# 4  For scheduled maintenance, the Capitol will be...          NaN
#
# [5 rows x 23 columns]

# %%
len(df_24)
# Out:
# 13645

# %%
# Keep only the columns we need: PostId, post_body_text, GoogleAudioText, EmbeddedContentText
df_24 = df_24[['PostId', 'post_body_text', 'GoogleAudioText', 'EmbeddedContentText', 'Platform', 'ChannelID']]

# make ' ' to NaN in GoogleAudioText
df_24['GoogleAudioText'] = df_24['GoogleAudioText'].replace(' ', pd.NA)
# make ' ' to NaN in EmbeddedContentText
df_24['EmbeddedContentText'] = df_24['EmbeddedContentText'].replace(' ', pd.NA)

# replace NaN with empty string
df_24['GoogleAudioText'] = df_24['GoogleAudioText'].fillna('')
df_24['EmbeddedContentText'] = df_24['EmbeddedContentText'].fillna('')

df_24['CombinedText'] = df_24['post_body_text'] + ' ' + df_24['GoogleAudioText'] + ' ' + df_24['EmbeddedContentText']

# %%
df_24.head()
# Out:
#       PostId                                     post_body_text  \
# 0  392353290  Happy Birthday to the @USNationalGuard @Nation...
# 1  392438642  Happy Birthday to the National Guard! Today, w...
# 2  392438644  Moments of harmony in the Iowa State Capitol. ...
# 3  392552204  Moments of harmony in the Iowa State Capitol. ...
# 4  392445383                                                NaN
#
#                                      GoogleAudioText  \
# 0
# 1
# 2   A-l-a-l-a-l-a-l-a-l-a-l-a-l-a-l-a-l-a-l-a-l-a...
# 3   Ae, ae, ae, ae, ae, ae, ae, ae, ae, ae, ae, a...
# 4
#
#                                  EmbeddedContentText         Platform  \
# 0                                                             Twitter
# 1                                                            Facebook
# 2                                                            Facebook
# 3                                                     InstagramDirect
# 4  For scheduled maintenance, the Capitol will be...         Facebook
#
#    ChannelID                                       CombinedText
# 0    8403193  Happy Birthday to the @USNationalGuard @Nation...
# 1    8402424  Happy Birthday to the National Guard! Today, w...
# 2    8402424  Moments of harmony in the Iowa State Capitol. ...
# 3   26302501  Moments of harmony in the Iowa State Capitol. ...
# 4    8894196                                                NaN

# %%
df_24.to_csv('text_2024.csv', index=False)
